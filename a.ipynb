# %%
import os

files=os.listdir("news_list_group_by_date")

nums=0

# %%
import pandas as pd

for file in files:
    df=pd.read_csv(f"news_list_group_by_date/{file}")
    nums+=len(df["label"])

print(nums)
# Out:
# 26220
